# %%
# %pip install pandas sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 1.1 MB/s eta 0:00:09
#    -- ------------------------------------- 0.5/10.0 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/10.0 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/10.0 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/10.0 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/10.0 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/10.0 MB 1.3 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/10.0 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/10.0 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/10.0 MB 1.3 MB/s eta 0:00:06
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\91827\Downloads\Pulse360\Notebooks

# %%
print(os.listdir())
# Out:
# ['01_Data_Ingestion_And_Profiling.ipynb', '02_Data_Cleaning_Feature_Engineering.ipynb', '03_Business_Insights_KPI.ipynb', '04_API_Integration_&_Data_Enrichment.ipynb', '05_Data_Warehouse_&_MySQL_ETL.ipynb']

# %%
print(os.listdir(".."))
# Out:
# ['API Data', 'Customer360', 'Data', 'KPIs and Summary Data', 'Notebooks']

# %%
print(os.listdir("Data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(os.listdir("Data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Data'

# %%
print(os.listdir("../Data"))
# Out:
# ['accounts_clean.csv', 'churn_events_clean.csv', 'Clean', 'feature_usage.csv', 'feature_usage_clean.csv', 'subscriptions.csv', 'subscriptions_clean.csv', 'support_ticket.csv', 'support_ticket_clean.csv']

# %%
print(os.listdir("../Data/Clean"))
# Out:
# []

# %%
accounts = pd.read_csv("../Data/accounts_clean.csv")
subscriptions = pd.read_csv("../Data/subscriptions_clean.csv")
feature_usage = pd.read_csv("../Data/feature_usage_clean.csv")
support_tickets = pd.read_csv("../Data/support_ticket_clean.csv")
churn_events = pd.read_csv("../Data/churn_events_clean.csv")

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:hxm%40viohja@localhost:3306/pulse360"
)

# %%
engine = create_engine(
    "mysql+pymysql://root:Hxm%40viohja@localhost:3306/pulse360"
)

# %%
with engine.connect() as conn:
    print("✅ Connected to MySQL Successfully!")
# Out:
# ✅ Connected to MySQL Successfully!

# %%
accounts.to_sql(
    name="accounts",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 500

# %%
subscriptions.to_sql(
    name="subscriptions",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 5000

# %%
feature_usage.to_sql(
    name="feature_usage",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 25000

# %%
support_tickets.to_sql(
    name="support_tickets",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 2000

# %%
churn_events.to_sql(
    name="churn_events",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 600
